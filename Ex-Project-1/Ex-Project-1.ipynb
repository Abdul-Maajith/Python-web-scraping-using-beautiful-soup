# %% [markdown]
# # Example Project - Scraping a dummy website!

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url = "https://keithgalli.github.io/web-scraping/"

# Load the webpage content.
r = requests.get(url + "webpage.html")

# Converting to a beautiful soup object
webpage = bs(r.content)
print(webpage)
# Out:
# <html><head>
#   <title>Keith Galli's Page</title>
#   <style>
#   table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
# </style>
# </head>
# <body>
#   <h1>Welcome to my page!</h1>
#   <img src="./images/selfie1.jpg" width="300px"/>
#   <h2>About me</h2>
#   <p>Hi, my name is Keith and I am a YouTuber who focuses on content related to programming, data science, and machine learning!</p>
# ...

# %% [markdown]
# # Grabing all of the social links from the webpages!
# * We must Do that in atleast three ways

# %%
# 1st way:
links = webpage.select("ul.socials a")
actual_links = [link["href"] for link in links]
print(actual_links)
# Out:
# ['https://www.instagram.com/keithgalli/', 'https://twitter.com/keithgalli', 'https://www.linkedin.com/in/keithgalli/', 'https://www.tiktok.com/@keithgalli']

# %%
# 2nd way:
ulinks = webpage.find("ul", attrs={"class": "socials"})
links = ulinks.find_all("a")
actual_links = [link["href"] for link in links]
print(actual_links)
# Out:
# ['https://www.instagram.com/keithgalli/', 'https://twitter.com/keithgalli', 'https://www.linkedin.com/in/keithgalli/', 'https://www.tiktok.com/@keithgalli']

# %%
# 3rd way:
links = webpage.select("li.social a")
actual_links = [link["href"] for link in links]
print(actual_links)
# Out:
# ['https://www.instagram.com/keithgalli/', 'https://twitter.com/keithgalli', 'https://www.linkedin.com/in/keithgalli/', 'https://www.tiktok.com/@keithgalli']

# %% [markdown]
# # Scraping the table in that website

# %%
import pandas as pd

table = webpage.select("table.hockey-stats")[0]
columns = table.find("thead").find_all("th")
column_names = [c.string for c in columns]

table_rows = table.find("tbody").find_all("tr")
l = []
for tr in table_rows:
    td = tr.find_all("td")
    row = [str(tr.get_text()).strip() for tr in td]
    l.append(row)
    
df = pd.DataFrame(l, columns=column_names)
df.loc[df["Team"] != "Did not play"]
# Out:
#          S                        Team    League  GP  G   A  TP PIM +/-     \
# 0  2014-15  MIT (Mass. Inst. of Tech.)   ACHA II  17  3   9  12  20      |
# 1  2015-16  MIT (Mass. Inst. of Tech.)   ACHA II   9  1   1   2   2      |
# 2  2016-17  MIT (Mass. Inst. of Tech.)   ACHA II  12  5   5  10   8   0  |
# 4  2018-19  MIT (Mass. Inst. of Tech.)  ACHA III   8  5  10  15   8      |
#
#   POST GP G A TP PIM +/-
# 0
# 1
# 2
# 4

# %% [markdown]
# # Grabbing all the fun facts that use the word "is"

# %%
import re

facts = webpage.select("ul.fun-facts li")
facts_with_is = [fact.find(string=re.compile("is")) for fact in facts]
facts_with_is = [fact.find_parent().get_text() for fact in facts_with_is if fact]
facts_with_is
# Out:
# ['Middle name is Ronald',
#  'Dunkin Donuts coffee is better than Starbucks',
#  "A favorite book series of mine is Ender's Game",
#  'Current video game of choice is Rocket League',
#  "The band that I've seen the most times live is the Zac Brown Band"]

# %% [markdown]
# # Downloading an image by scraping!

# %%
img = webpage.select("div.row div.column img")
img_url = img[0]["src"]
full_url = url + img_url

# Downloading the image data!
img_data = requests.get(full_url).content
with open("lake_como.jpg", "wb") as handler:
    handler.write(img_data)

# %% [markdown]
# # Solving the mystery challenge!

# %%
files = webpage.select("div.block a")
href = [f["href"] for f in files]

for f in href:
    full_url = url + f
    page = requests.get(full_url)
    bs_page = bs(page.content)
    secret_word_element = bs_page.find("p", attrs={"id": "secret-word"})
    print(secret_word_element.string)
# Out:
# Make
# sure
# to
# smash
# that
# like
# button
# and
# subscribe
# !!!
